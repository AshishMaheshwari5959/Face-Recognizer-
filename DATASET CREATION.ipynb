# %%
import cv2
import numpy as np
from os import listdir
from os.path import isfile, join

# %%
##to scan photos for training of Ashish
cap = cv2.VideoCapture(0 , cv2.CAP_DSHOW)
count = 0
while True :
    status , photo = cap.read()
    face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    face_cor = face_model.detectMultiScale(photo)
    if len(face_cor) != 0:
        count = count +1
        x , y , h , w = face_cor[0,0] , face_cor[0,1] , face_cor[0,2] , face_cor[0,3]
        crop_photo = photo[y:y+h , x:x+w]
        crop_resize = cv2.resize(crop_photo,(224,224))
        file_name_path = 'Faces/train/Ashish/image' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, crop_resize)
        cv2.putText(crop_resize , str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper' , crop_resize)
    if cv2.waitKey(1) == 13 or count == 1000 :
        break
cv2.destroyAllWindows()
cap.release()

# %%
##to scan photos for training of Poorvi
cap = cv2.VideoCapture(0 , cv2.CAP_DSHOW)
count = 0
while True :
    status , photo = cap.read()
    face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    face_cor = face_model.detectMultiScale(photo)
    if len(face_cor) != 0:
        count = count +1
        x , y , h , w = face_cor[0,0] , face_cor[0,1] , face_cor[0,2] , face_cor[0,3]
        crop_photo = photo[y:y+h , x:x+w]
        crop_resize = cv2.resize(crop_photo,(224,224))
        file_name_path = 'Faces/train/Poorvi/image' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, crop_resize)
        cv2.putText(crop_resize , str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper' , crop_resize)
    if cv2.waitKey(1) == 13 or count == 1000 :
        break
cv2.destroyAllWindows()
cap.release()

# %%
##to scan photos for training of Pushpa
cap = cv2.VideoCapture(0 , cv2.CAP_DSHOW)
count = 0
while True :
    status , photo = cap.read()
    face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    face_cor = face_model.detectMultiScale(photo)
    if len(face_cor) != 0:
        count = count +1
        x , y , h , w = face_cor[0,0] , face_cor[0,1] , face_cor[0,2] , face_cor[0,3]
        crop_photo = photo[y:y+h , x:x+w]
        crop_resize = cv2.resize(crop_photo,(224,224))
        file_name_path = 'Faces/train/Pushpa/image' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, crop_resize)
        cv2.putText(crop_resize , str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper' , crop_resize)
    if cv2.waitKey(1) == 13 or count == 1000 :
        break
cv2.destroyAllWindows()
cap.release()

# %%
##to scan photos for training of Shobha
cap = cv2.VideoCapture(0 , cv2.CAP_DSHOW)
count = 0
while True :
    status , photo = cap.read()
    face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    face_cor = face_model.detectMultiScale(photo)
    if len(face_cor) != 0:
        count = count +1
        x , y , h , w = face_cor[0,0] , face_cor[0,1] , face_cor[0,2] , face_cor[0,3]
        crop_photo = photo[y:y+h , x:x+w]
        crop_resize = cv2.resize(crop_photo,(224,224))
        file_name_path = 'Faces/train/Shobha/image' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, crop_resize)
        cv2.putText(crop_resize , str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper' , crop_resize)
    if cv2.waitKey(1) == 13 or count == 1000 :
        break
cv2.destroyAllWindows()
cap.release()

# %%
##to scan photos for testing of Ashish
cap = cv2.VideoCapture(0 , cv2.CAP_DSHOW)
count = 0
while True :
    status , photo = cap.read()
    face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    face_cor = face_model.detectMultiScale(photo)
    if len(face_cor) != 0:
        count = count +1
        x , y , h , w = face_cor[0,0] , face_cor[0,1] , face_cor[0,2] , face_cor[0,3]
        crop_photo = photo[y:y+h , x:x+w]
        crop_resize = cv2.resize(crop_photo,(224,224))
        file_name_path = 'Faces/validation/Ashish/image' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, crop_resize)
        cv2.putText(crop_resize , str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper' , crop_resize)
    if cv2.waitKey(1) == 13 or count == 1000 :
        break
cv2.destroyAllWindows()
cap.release()

# %%
##to scan photos for testing of Poorvi
cap = cv2.VideoCapture(0 , cv2.CAP_DSHOW)
count = 0
while True :
    status , photo = cap.read()
    face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    face_cor = face_model.detectMultiScale(photo)
    if len(face_cor) != 0:
        count = count +1
        x , y , h , w = face_cor[0,0] , face_cor[0,1] , face_cor[0,2] , face_cor[0,3]
        crop_photo = photo[y:y+h , x:x+w]
        crop_resize = cv2.resize(crop_photo,(224,224))
        file_name_path = 'Faces/validation/Poorvi/image' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, crop_resize)
        cv2.putText(crop_resize , str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper' , crop_resize)
    if cv2.waitKey(1) == 13 or count == 1000 :
        break
cv2.destroyAllWindows()
cap.release()

# %%
##to scan photos for testing of Pushpa
cap = cv2.VideoCapture(0 , cv2.CAP_DSHOW)
count = 0
while True :
    status , photo = cap.read()
    face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    face_cor = face_model.detectMultiScale(photo)
    if len(face_cor) != 0:
        count = count +1
        x , y , h , w = face_cor[0,0] , face_cor[0,1] , face_cor[0,2] , face_cor[0,3]
        crop_photo = photo[y:y+h , x:x+w]
        crop_resize = cv2.resize(crop_photo,(224,224))
        file_name_path = 'Faces/validation/Pushpa/image' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, crop_resize)
        cv2.putText(crop_resize , str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper' , crop_resize)
    if cv2.waitKey(1) == 13 or count == 1000 :
        break
cv2.destroyAllWindows()
cap.release()

# %%
##to scan photos for testing of Shobha
cap = cv2.VideoCapture(0 , cv2.CAP_DSHOW)
count = 0
while True :
    status , photo = cap.read()
    face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    face_cor = face_model.detectMultiScale(photo)
    if len(face_cor) != 0:
        count = count +1
        x , y , h , w = face_cor[0,0] , face_cor[0,1] , face_cor[0,2] , face_cor[0,3]
        crop_photo = photo[y:y+h , x:x+w]
        crop_resize = cv2.resize(crop_photo,(224,224))
        file_name_path = 'Faces/validation/Shobha/image' + str(count) + '.jpg'
        cv2.imwrite(file_name_path, crop_resize)
        cv2.putText(crop_resize , str(count), (50, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Cropper' , crop_resize)
    if cv2.waitKey(1) == 13 or count == 1000 :
        break
cv2.destroyAllWindows()
cap.release()
